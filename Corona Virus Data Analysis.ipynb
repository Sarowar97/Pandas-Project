# %%
import pandas as pd
import numpy as pd

# %%
confirmed_cases_url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv" 
recovered_cases_url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv"
death_cases_url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv"

# %%
df_cofirmed = pd.read_csv(confirmed_cases_url)

# %%
df_cofirmed.tail(5)
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 268            NaN             Vietnam  14.058324  108.277199        0
# 269            NaN  West Bank and Gaza  31.952200   35.233200        0
# 270            NaN               Yemen  15.552727   48.516388        0
# 271            NaN              Zambia -13.133897   27.849332        0
# 272            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/6/21  2/7/21  2/8/21  \
# 268        2        2        2        2        2  ...    1985    2001    2050
# 269        0        0        0        0        0  ...  162029  162601  163213
# 270        0        0        0        0        0  ...    2127    2127    2131
# 271        0        0        0        0        0  ...   61427   62633   63573
# 272        0        0        0        0        0  ...   34487   34552   34658
#
#      2/9/21  2/10/21  2/11/21  2/12/21  2/13/21  2/14/21  2/15/21
# ...

# %%
df_cofirmed.shape
# Out:
# (273, 395)

# %%
df_cofirmed.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '2/6/21', '2/7/21', '2/8/21', '2/9/21', '2/10/21', '2/11/21', '2/12/21',
#        '2/13/21', '2/14/21', '2/15/21'],
#       dtype='object', length=395)

# %%
df_cofirmed.melt(id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'])
# Out:
#        Province/State      Country/Region        Lat        Long variable  \
# 0                 NaN         Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN             Albania  41.153300   20.168300  1/22/20
# 2                 NaN             Algeria  28.033900    1.659600  1/22/20
# 3                 NaN             Andorra  42.506300    1.521800  1/22/20
# 4                 NaN              Angola -11.202700   17.873900  1/22/20
# ...               ...                 ...        ...         ...      ...
# 106738            NaN             Vietnam  14.058324  108.277199  2/15/21
# 106739            NaN  West Bank and Gaza  31.952200   35.233200  2/15/21
# 106740            NaN               Yemen  15.552727   48.516388  2/15/21
# 106741            NaN              Zambia -13.133897   27.849332  2/15/21
# 106742            NaN            Zimbabwe -19.015438   29.154857  2/15/21
#
#          value
# 0            0
# 1            0
# 2            0
# ...

# %%
df_cofirmed = df_cofirmed.melt(id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'])

# %%
df_cofirmed
# Out:
#        Province/State      Country/Region        Lat        Long variable  \
# 0                 NaN         Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN             Albania  41.153300   20.168300  1/22/20
# 2                 NaN             Algeria  28.033900    1.659600  1/22/20
# 3                 NaN             Andorra  42.506300    1.521800  1/22/20
# 4                 NaN              Angola -11.202700   17.873900  1/22/20
# ...               ...                 ...        ...         ...      ...
# 106738            NaN             Vietnam  14.058324  108.277199  2/15/21
# 106739            NaN  West Bank and Gaza  31.952200   35.233200  2/15/21
# 106740            NaN               Yemen  15.552727   48.516388  2/15/21
# 106741            NaN              Zambia -13.133897   27.849332  2/15/21
# 106742            NaN            Zimbabwe -19.015438   29.154857  2/15/21
#
#          value
# 0            0
# 1            0
# 2            0
# ...

# %%
df_cofirmed.rename(columns = {'variable':'Date','value':'Confirmed'},inplace = True)

# %%
df_cofirmed
# Out:
#        Province/State      Country/Region        Lat        Long     Date  \
# 0                 NaN         Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN             Albania  41.153300   20.168300  1/22/20
# 2                 NaN             Algeria  28.033900    1.659600  1/22/20
# 3                 NaN             Andorra  42.506300    1.521800  1/22/20
# 4                 NaN              Angola -11.202700   17.873900  1/22/20
# ...               ...                 ...        ...         ...      ...
# 106738            NaN             Vietnam  14.058324  108.277199  2/15/21
# 106739            NaN  West Bank and Gaza  31.952200   35.233200  2/15/21
# 106740            NaN               Yemen  15.552727   48.516388  2/15/21
# 106741            NaN              Zambia -13.133897   27.849332  2/15/21
# 106742            NaN            Zimbabwe -19.015438   29.154857  2/15/21
#
#         Confirmed
# 0               0
# 1               0
# 2               0
# ...

# %%
def get_n_melt_data(data_url,case_type):
    df= pd.read_csv(data_url)
    melted_df= df.melt(id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'])
    melted_df.rename(columns = {'variable':'Date','value':case_type},inplace = True)
    return melted_df

# %%
recovered_df = get_n_melt_data(recovered_cases_url,"Recovered")
death_df = get_n_melt_data(death_cases_url,"Death")

# %%
death_df.tail(5)
# Out:
#        Province/State      Country/Region        Lat        Long     Date  \
# 106738            NaN             Vietnam  14.058324  108.277199  2/15/21
# 106739            NaN  West Bank and Gaza  31.952200   35.233200  2/15/21
# 106740            NaN               Yemen  15.552727   48.516388  2/15/21
# 106741            NaN              Zambia -13.133897   27.849332  2/15/21
# 106742            NaN            Zimbabwe -19.015438   29.154857  2/15/21
#
#         Death
# 106738     35
# 106739   1936
# 106740    617
# 106741    959
# 106742   1410

# %%
(death_df['Death']).shape
# Out:
# (100878, 6)

# %%
recovered_df.shape
# Out:
# (106743, 6)

# %%
df_cofirmed.shape
# Out:
# (106743, 6)

# %%
df_cofirmed.head(5)
# Out:
#   Province/State Country/Region       Lat       Long     Date  Confirmed
# 0            NaN    Afghanistan  33.93911  67.709953  1/22/20          0
# 1            NaN        Albania  41.15330  20.168300  1/22/20          0
# 2            NaN        Algeria  28.03390   1.659600  1/22/20          0
# 3            NaN        Andorra  42.50630   1.521800  1/22/20          0
# 4            NaN         Angola -11.20270  17.873900  1/22/20          0

# %%
new_df = df_cofirmed.join(death_df['Death'])

# %%
new_df
# Out:
#        Province/State      Country/Region        Lat        Long     Date  \
# 0                 NaN         Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN             Albania  41.153300   20.168300  1/22/20
# 2                 NaN             Algeria  28.033900    1.659600  1/22/20
# 3                 NaN             Andorra  42.506300    1.521800  1/22/20
# 4                 NaN              Angola -11.202700   17.873900  1/22/20
# ...               ...                 ...        ...         ...      ...
# 106738            NaN             Vietnam  14.058324  108.277199  2/15/21
# 106739            NaN  West Bank and Gaza  31.952200   35.233200  2/15/21
# 106740            NaN               Yemen  15.552727   48.516388  2/15/21
# 106741            NaN              Zambia -13.133897   27.849332  2/15/21
# 106742            NaN            Zimbabwe -19.015438   29.154857  2/15/21
#
#         Confirmed  Death
# 0               0      0
# 1               0      0
# ...

# %%
new_df.to_csv(r"C:\Users\Sarowar\Downloads\coronavirus_update_dataset.csv")
