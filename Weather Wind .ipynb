# %%
import pandas as pd

# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\Sarowar'

# %%
data=pd.read_csv(r‪‪‪‪‪‪'‪C:\Users\Sarowar\Downloads\1. Weather Data.csv')
# Out:
#   File "<ipython-input-8-d823857033c9>", line 1
#     data=pd.read_csv(r‪‪‪‪‪‪'‪C:\Users\Sarowar\Downloads\1. Weather Data.csv')
#                            ^
# SyntaxError: invalid character in identifier

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data.tail(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f36cd83228b5> in <module>
# ----> 1 data.tail(10)
#
# NameError: name 'data' is not defined

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-047ed65ff157> in <module>
# ----> 1 data.shape
#
# NameError: name 'data' is not defined

# %%
data.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e47a7d363e09> in <module>
# ----> 1 data.index
#
# NameError: name 'data' is not defined

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data["Weather"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data["Weather"].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date/Time          8784 non-null   object
#  1   Temp_C             8784 non-null   float64
#  2   Dew Point Temp_C   8784 non-null   float64
#  3   Rel Hum_%          8784 non-null   int64
#  4   Wind Speed_km/h    8784 non-null   int64
#  5   Visibility_km      8784 non-null   float64
#  6   Press_kPa          8784 non-null   float64
#  7   Weather Condition  8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
## Find The Unique value Of Wind Speed_km/h ##

# %%
data.head(15)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8              -3.9         86                4
# 1    1/1/2012 1:00    -1.8              -3.7         87                4
# 2    1/1/2012 2:00    -1.8              -3.4         89                7
# 3    1/1/2012 3:00    -1.5              -3.2         88                6
# 4    1/1/2012 4:00    -1.5              -3.3         88                7
# 5    1/1/2012 5:00    -1.4              -3.3         87                9
# 6    1/1/2012 6:00    -1.5              -3.1         89                7
# 7    1/1/2012 7:00    -1.4              -3.6         85                7
# 8    1/1/2012 8:00    -1.4              -3.6         85                9
# 9    1/1/2012 9:00    -1.3              -3.1         88               15
# 10  1/1/2012 10:00    -1.0              -2.3         91                9
# 11  1/1/2012 11:00    -0.5              -2.1         89                7
# ...

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data["Wind Speed_km/h"].nunique()
# Out:
# 34

# %%
data["Wind Speed_km/h"].unique() #Answer
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
#### Find The Number of Times When The Weather IS Exactly Clear #######

# %%
data.head(5)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data["Weather"].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data[data.Weather == 'Clear'].head(5)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
# 115  1/5/2012 19:00    -9.2             -15.4         61                7
# 116  1/5/2012 20:00    -9.8             -15.7         62                9
# 117  1/5/2012 21:00    -9.0             -14.8         63               13
#
#      Visibility_km  Press_kPa Weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear
# 115           25.0     100.80   Clear
# 116           25.0     100.83   Clear
# 117           25.0     100.83   Clear

# %%
## groupby()

data.groupby('Weather').get_group('Clear').head(5)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
# 115  1/5/2012 19:00    -9.2             -15.4         61                7
# 116  1/5/2012 20:00    -9.8             -15.7         62                9
# 117  1/5/2012 21:00    -9.0             -14.8         63               13
#
#      Visibility_km  Press_kPa Weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear
# 115           25.0     100.80   Clear
# 116           25.0     100.83   Clear
# 117           25.0     100.83   Clear

# %%
# Find The Number of Times When The Wind Spped is 4km/h ###

# %%
data[data['Wind Speed_km/h'] == 4].head(5)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8              -3.9         86                4
# 1    1/1/2012 1:00    -1.8              -3.7         87                4
# 96   1/5/2012 0:00    -8.8             -11.7         79                4
# 101  1/5/2012 5:00    -7.0              -9.5         82                4
# 146  1/7/2012 2:00    -8.1             -11.1         79                4
#
#      Visibility_km  Press_kPa Weather
# 0              8.0     101.24     Fog
# 1              8.0     101.24     Fog
# 96             9.7     100.32    Snow
# 101            4.0     100.19    Snow
# 146           19.3     100.15  Cloudy

# %%
data.groupby('Wind Speed_km/h').get_group(4).head(5)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8              -3.9         86                4
# 1    1/1/2012 1:00    -1.8              -3.7         87                4
# 96   1/5/2012 0:00    -8.8             -11.7         79                4
# 101  1/5/2012 5:00    -7.0              -9.5         82                4
# 146  1/7/2012 2:00    -8.1             -11.1         79                4
#
#      Visibility_km  Press_kPa Weather
# 0              8.0     101.24     Fog
# 1              8.0     101.24     Fog
# 96             9.7     100.32    Snow
# 101            4.0     100.19    Snow
# 146           19.3     100.15  Cloudy

# %%
# Null Value In Data #

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
# Rename Weather Coloumn #

# %%
data.rename(columns = {'Weather':'Weather Condition'})
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.rename(columns = {'Weather':'Weather Condition'},inplace = True)

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
# mean value of Visibility_km #

# %%
data.Visibility_km.mean()
# Out:
# 27.66444672131151

# %%
## What is the stranderd diveration of presuure in this data ##

# %%
data.Press_kPa.std()
# Out:
# 0.8440047459486474

# %%
## What is the variance of Rel Hum_ in this data ###

# %%
data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %%
## Find all Instances when the snow is recordded ##

# %%
data.head(5)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data['Weather Condition'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data[data['Weather Condition'] == "Snow"].head(5)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55   1/3/2012 7:00   -14.0             -19.5         63               19
# 84  1/4/2012 12:00   -13.7             -21.7         51               11
# 86  1/4/2012 14:00   -11.3             -19.0         53                7
# 87  1/4/2012 15:00   -10.2             -16.3         61               11
# 88  1/4/2012 16:00    -9.4             -15.5         61               13
#
#     Visibility_km  Press_kPa Weather Condition
# 55           25.0     100.95              Snow
# 84           24.1     101.25              Snow
# 86           19.3     100.97              Snow
# 87            9.7     100.89              Snow
# 88           19.3     100.79              Snow

# %%
data.groupby('Weather Condition').get_group('Snow').head(5)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55   1/3/2012 7:00   -14.0             -19.5         63               19
# 84  1/4/2012 12:00   -13.7             -21.7         51               11
# 86  1/4/2012 14:00   -11.3             -19.0         53                7
# 87  1/4/2012 15:00   -10.2             -16.3         61               11
# 88  1/4/2012 16:00    -9.4             -15.5         61               13
#
#     Visibility_km  Press_kPa Weather Condition
# 55           25.0     100.95              Snow
# 84           24.1     101.25              Snow
# 86           19.3     100.97              Snow
# 87            9.7     100.89              Snow
# 88           19.3     100.79              Snow

# %%
data[data['Weather Condition'].str.contains('Snow')].tail(10)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8774  12/31/2012 14:00    -3.4              -5.7         84                6
# 8775  12/31/2012 15:00    -2.3              -4.6         84                9
# 8776  12/31/2012 16:00    -1.4              -4.0         82               13
# 8777  12/31/2012 17:00    -1.1              -3.3         85               19
# 8778  12/31/2012 18:00    -1.3              -3.1         88               17
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather Condition
# 8774           11.3     100.57              Snow
# ...

# %%
## Find The All instances When The wind Spped is above 24 and visiability is 25 ###

# %%
data [(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)].head(5)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23  1/1/2012 23:00     5.3               2.0         79               30
# 24   1/2/2012 0:00     5.2               1.5         77               35
# 25   1/2/2012 1:00     4.6               0.0         72               39
# 26   1/2/2012 2:00     3.9              -0.9         71               32
# 27   1/2/2012 3:00     3.7              -1.5         69               33
#
#     Visibility_km  Press_kPa Weather Condition
# 23           25.0      99.31            Cloudy
# 24           25.0      99.26      Rain Showers
# 25           25.0      99.26            Cloudy
# 26           25.0      99.26     Mostly Cloudy
# 27           25.0      99.30     Mostly Cloudy

# %%
## MEan value each coloumn against weather condition

# %%
data.groupby('Weather Condition').mean().head(5)
# Out:
#                            Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Condition
# Clear                    6.825716          0.089367  64.497738
# Cloudy                   7.970544          2.375810  69.592593
# Drizzle                  7.353659          5.504878  88.243902
# Drizzle,Fog              8.067500          7.033750  93.275000
# Drizzle,Ice Pellets,Fog  0.400000         -0.700000  92.000000
#
#                          Wind Speed_km/h  Visibility_km   Press_kPa
# Weather Condition
# Clear                          10.557315      30.153243  101.587443
# Cloudy                         16.127315      26.625752  100.911441
# Drizzle                        16.097561      17.931707  100.435366
# Drizzle,Fog                    11.862500       5.257500  100.786625
# Drizzle,Ice Pellets,Fog        20.000000       4.000000  100.790000

# %%
## min and max value each coloumn against weather condition

# %%
data.groupby('Weather Condition').min().head(5)
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Condition
# Clear                     1/11/2012 1:00   -23.3             -28.5         20
# Cloudy                    1/1/2012 17:00   -21.4             -26.8         18
# Drizzle                  1/23/2012 21:00     1.1              -0.2         74
# Drizzle,Fog              1/23/2012 20:00     0.0              -1.6         85
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7         92
#
#                          Wind Speed_km/h  Visibility_km  Press_kPa
# Weather Condition
# Clear                                  0           11.3      99.52
# Cloudy                                 0           11.3      98.39
# Drizzle                                0            6.4      97.84
# Drizzle,Fog                            0            1.0      98.65
# Drizzle,Ice Pellets,Fog               20            4.0     100.79

# %%
data.groupby('Weather Condition').max().head(5)
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Condition
# Clear                      9/9/2012 5:00    32.8              20.4         99
# Cloudy                    9/9/2012 23:00    30.5              22.6         99
# Drizzle                   9/30/2012 3:00    18.8              17.7         96
# Drizzle,Fog               9/30/2012 2:00    19.9              19.1        100
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7         92
#
#                          Wind Speed_km/h  Visibility_km  Press_kPa
# Weather Condition
# Clear                                 33           48.3     103.63
# Cloudy                                54           48.3     103.65
# Drizzle                               30           25.0     101.56
# Drizzle,Fog                           28            9.7     102.07
# Drizzle,Ice Pellets,Fog               20            4.0     100.79

# %%
#Show All the records where weather condition is fog##

# %%
data[data['Weather Condition'] == 'Fog'].head(5)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog
# 4            4.8     101.23               Fog
# 5            6.4     101.27               Fog
# 6            6.4     101.29               Fog

# %%
## Find the instances when "Weather is clear" or "visibality is above 40"

# %%
data[(data['Weather Condition'] == 'Clear') | (data['Visibility_km'] > 40)].head(5)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 106  1/5/2012 10:00    -6.0             -10.0         73               17
# 107  1/5/2012 11:00    -5.6             -10.2         70               22
# 108  1/5/2012 12:00    -4.7              -9.6         69               20
# 109  1/5/2012 13:00    -4.4              -9.7         66               26
#
#      Visibility_km  Press_kPa Weather Condition
# 67            25.0     101.74             Clear
# 106           48.3     100.45      Mainly Clear
# 107           48.3     100.41      Mainly Clear
# 108           48.3     100.38      Mainly Clear
# 109           48.3     100.40      Mainly Clear

# %%
## Find the instances when "Weather is clear" and Rel Humadity is greater than 50

# %%
data[(data['Weather Condition'] == 'Clear') &(data['Rel Hum_%'] >50) | (data['Visibility_km'] >40)].head(10)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106  1/5/2012 10:00    -6.0             -10.0         73               17
# 107  1/5/2012 11:00    -5.6             -10.2         70               22
# 108  1/5/2012 12:00    -4.7              -9.6         69               20
# 109  1/5/2012 13:00    -4.4              -9.7         66               26
# 110  1/5/2012 14:00    -5.1             -10.7         65               22
# 111  1/5/2012 15:00    -4.3             -12.0         55               26
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
# 115  1/5/2012 19:00    -9.2             -15.4         61                7
# 116  1/5/2012 20:00    -9.8             -15.7         62                9
# 117  1/5/2012 21:00    -9.0             -14.8         63               13
#
#      Visibility_km  Press_kPa Weather Condition
# 106           48.3     100.45      Mainly Clear
# 107           48.3     100.41      Mainly Clear
# ...
