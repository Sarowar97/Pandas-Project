# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Sarowar\Downloads\Compressed\Data-Cleaning-Practical-Examples-master\Data_Cleaning_In_Python_Working_with_Str\dataset.csv')

# %%
df.head(4)
# Out:
#    id         Full Name Date of Birth                         email  gender  \
# 0   1       Salim Pound     2/12/2018           spound0@spotify.com    Male
# 1   2    Madelene Lutas     9/20/2018                mlutas1@si.edu  Female
# 2   3  Dolli Swanbourne    11/18/2018  dswanbourne2@istockphoto.com  Female
# 3   4   Graeme Croisier     9/29/2018      gcroisier3@parallels.com    Male
#
#                            Job    Company                 Country  \
# 0                       Editor  Gigashots                  Israel
# 1                 VP Marketing     Wikivu                Mongolia
# 2          Associate Professor    Dabfeed                 Vietnam
# 3  Mechanical Systems Engineer     Trudoo  Bosnia and Herzegovina
#
#                                Salary         Phone  \
# 0  19QtDp5HkyuZZqwwqzYPSSLuA7MXFCwfKL  610-741-3882
# 1  17ADLE8HiTj7m1tTbzboLDn7eiZ4TjetzZ  221-725-8860
# 2  16ThVxH72YAXWiEBeBZB1WYtXcfJMwUtoB  303-720-8280
# ...

# %%
df['Full Name'].head(4)
# Out:
# 0         Salim Pound
# 1      Madelene Lutas
# 2    Dolli Swanbourne
# 3     Graeme Croisier
# Name: Full Name, dtype: object

# %%
df['Full Name'].str.split(" ")
# Out:
# 0              [Salim, Pound]
# 1           [Madelene, Lutas]
# 2         [Dolli, Swanbourne]
# 3          [Graeme, Croisier]
# 4           [Jillana, Physic]
#                 ...
# 995      [Willie, Gravestone]
# 996       [Samara, McRitchie]
# 997    [Joceline, Josefowicz]
# 998          [Andrei, Lestor]
# 999         [Nikkie, Langtry]
# Name: Full Name, Length: 1000, dtype: object

# %%
df['Full Name'].str.split(" ").str.get(0)
# Out:
# 0         Salim
# 1      Madelene
# 2         Dolli
# 3        Graeme
# 4       Jillana
#          ...
# 995      Willie
# 996      Samara
# 997    Joceline
# 998      Andrei
# 999      Nikkie
# Name: Full Name, Length: 1000, dtype: object

# %%
df['First name']=df['Full Name'].str.split(" ").str.get(0)

# %%
df['First name']
# Out:
# 0         Salim
# 1      Madelene
# 2         Dolli
# 3        Graeme
# 4       Jillana
#          ...
# 995      Willie
# 996      Samara
# 997    Joceline
# 998      Andrei
# 999      Nikkie
# Name: First name, Length: 1000, dtype: object

# %%
df['Last name']=df['Full Name'].str.split(" ").str.get(1)

# %%
df['Last name']
# Out:
# 0           Pound
# 1           Lutas
# 2      Swanbourne
# 3        Croisier
# 4          Physic
#           ...
# 995    Gravestone
# 996     McRitchie
# 997    Josefowicz
# 998        Lestor
# 999       Langtry
# Name: Last name, Length: 1000, dtype: object

# %%
df['Full Name'].str.split(" ",n=1,expand=True)
# Out:
#             0           1
# 0       Salim       Pound
# 1    Madelene       Lutas
# 2       Dolli  Swanbourne
# 3      Graeme    Croisier
# 4     Jillana      Physic
# ..        ...         ...
# 995    Willie  Gravestone
# 996    Samara   McRitchie
# 997  Joceline  Josefowicz
# 998    Andrei      Lestor
# 999    Nikkie     Langtry
#
# [1000 rows x 2 columns]

# %%
df.head(4)
# Out:
#    id         Full Name Date of Birth                         email  gender  \
# 0   1       Salim Pound     2/12/2018           spound0@spotify.com    Male
# 1   2    Madelene Lutas     9/20/2018                mlutas1@si.edu  Female
# 2   3  Dolli Swanbourne    11/18/2018  dswanbourne2@istockphoto.com  Female
# 3   4   Graeme Croisier     9/29/2018      gcroisier3@parallels.com    Male
#
#                            Job    Company                 Country  \
# 0                       Editor  Gigashots                  Israel
# 1                 VP Marketing     Wikivu                Mongolia
# 2          Associate Professor    Dabfeed                 Vietnam
# 3  Mechanical Systems Engineer     Trudoo  Bosnia and Herzegovina
#
#                                Salary         Phone  \
# 0  19QtDp5HkyuZZqwwqzYPSSLuA7MXFCwfKL  610-741-3882
# 1  17ADLE8HiTj7m1tTbzboLDn7eiZ4TjetzZ  221-725-8860
# 2  16ThVxH72YAXWiEBeBZB1WYtXcfJMwUtoB  303-720-8280
# ...

# %%
####################

# %%
df['Income.1']
# Out:
# 0      $46476.6380809961
# 1      $54174.6879482406
# 2      $5449.87334818567
# 3      $46784.6308786279
# 4      $57486.4955595568
#              ...
# 995    $33868.4041871395
# 996    $46290.7803582873
# 997    $24202.0325327311
# 998    $54316.2938322092
# 999               $56477
# Name: Income.1, Length: 1000, dtype: object

# %%
df['Income.1'].dtypes
# Out:
# dtype('O')

# %%
df['Income.1'].str.replace("$"," ")
# Out:
# 0       46476.6380809961
# 1       54174.6879482406
# 2       5449.87334818567
# 3       46784.6308786279
# 4       57486.4955595568
#              ...
# 995     33868.4041871395
# 996     46290.7803582873
# 997     24202.0325327311
# 998     54316.2938322092
# 999                56477
# Name: Income.1, Length: 1000, dtype: object

# %%
df.Salary
# Out:
# 0      19QtDp5HkyuZZqwwqzYPSSLuA7MXFCwfKL
# 1      17ADLE8HiTj7m1tTbzboLDn7eiZ4TjetzZ
# 2      16ThVxH72YAXWiEBeBZB1WYtXcfJMwUtoB
# 3      1JLUVwmjHvxgh53C7Afie3pWbjrYxV9Fnx
# 4      1DaEUNoAWL68pnvThSM5eBYgQMTv9mKyFG
#                       ...
# 995    1NhweMA6xVPvFfYyQfRvusazTkMvuP8kap
# 996     1t9C9e457Z6efZCZ46Ywm84Xgw79WEBW9
# 997    13pFvvCyTz5AFNhk7ugp9G6aYA89wVJFns
# 998    1CTz1ejJhKvKUvV7tMgQ97wCguJpRAVZan
# 999     1JFRCVhkbkR9TFrS2RKezc7HKoteeUHzR
# Name: Salary, Length: 1000, dtype: object

# %%
df.Salary.str.contains('17')
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Salary, Length: 1000, dtype: bool

# %%
df[df.Salary.str.contains('17')]
# Out:
#       id             Full Name Date of Birth  \
# 1      2        Madelene Lutas     9/20/2018
# 23    24        Darleen McGinn     4/28/2018
# 39    40          Gusta Guihen    10/29/2018
# 58    59        Aron Edworthye     4/29/2018
# 62    63  Douglas Whistlecroft     2/15/2018
# ..   ...                   ...           ...
# 907  908         Cristin Orpin     4/18/2018
# 925  926        Odelia Hintzer    10/27/2018
# 965  966      Francklyn Pistol      5/5/2018
# 966  967     Avrit Rosencrantz    10/14/2018
# 989  990      Kayley Brothwood     4/12/2018
#
#                                       email  gender  \
# 1                            mlutas1@si.edu  Female
# 23                     dmcginnn@typepad.com  Female
# 39                     gguihen13@weebly.com  Female
# 58                    aedworthye1m@youtu.be    Male
# 62   dwhistlecroft1q@networkadvertising.org    Male
# ..                                      ...     ...
# ...

# %%
df.Salary.str.contains('17|19')
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Salary, Length: 1000, dtype: bool

# %%
df.Salary.str.match('17|19')
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Salary, Length: 1000, dtype: bool

# %%
df[df.Quote.str.match('Operative') ].head(4)
# Out:
#       id      Full Name Date of Birth                   email  gender  \
# 7      8    Melina Boon    12/18/2017        mboon7@weibo.com  Female
# 110  111       Ema Buck     6/29/2018            ebuck32@g.co  Female
# 138  139  Hunt Dockrill    10/11/2018   hdockrill3u@chron.com    Male
# 164  165  Ron Matherson     9/18/2018  rmatherson4k@amazon.de    Male
#
#                        Job     Company      Country  \
# 7        Assistant Manager    Kanoodle     Colombia
# 110         Civil Engineer  Linkbridge        China
# 138  Chief Design Engineer     Dabvine         Iran
# 164       Internal Auditor       Rooxo  Philippines
#
#                                  Salary         Phone  \
# 7    1BRHmiaJur3qG1H4H1WsU8VJLKHwxvqRwF  280-484-7263
# 110  1KaWubTcNW5yc9YvdSDcAsJ7AKCr3BbUXq  773-675-4907
# 138  16rhNv6bDooDsyscw72Yq4YQDgbe9kHHn1  243-149-7140
# 164  1PuoqLCBv7DNEzy9WxAg72jcKeZxYU1EXc  950-659-1921
#
# ...

# %%
df['First name'] + df['email']
# Out:
# 0                   Salimspound0@spotify.com
# 1                     Madelenemlutas1@si.edu
# 2          Dollidswanbourne2@istockphoto.com
# 3             Graemegcroisier3@parallels.com
# 4             Jillanajphysic4@yellowbook.com
#                        ...
# 995          Williewgravestonern@typepad.com
# 996        Samarasmcritchiero@wikispaces.com
# 997    Jocelinejjosefowiczrp@statcounter.com
# 998              Andreialestorrq@storify.com
# 999        Nikkienlangtryrr@sciencedaily.com
# Length: 1000, dtype: object

# %%
duplicated()
# Out:
# 0                   Salim_spound0@spotify.com
# 1                     Madelene_mlutas1@si.edu
# 2          Dolli_dswanbourne2@istockphoto.com
# 3             Graeme_gcroisier3@parallels.com
# 4             Jillana_jphysic4@yellowbook.com
#                         ...
# 995          Willie_wgravestonern@typepad.com
# 996        Samara_smcritchiero@wikispaces.com
# 997    Joceline_jjosefowiczrp@statcounter.com
# 998              Andrei_alestorrq@storify.com
# 999        Nikkie_nlangtryrr@sciencedaily.com
# Length: 1000, dtype: object

# %%
df.loc[:,df.columns!='email']
df.loc[:,df.columns!='gender']
# Out:
#        id            Full Name Date of Birth                          email  \
# 0       1          Salim Pound     2/12/2018            spound0@spotify.com
# 1       2       Madelene Lutas     9/20/2018                 mlutas1@si.edu
# 2       3     Dolli Swanbourne    11/18/2018   dswanbourne2@istockphoto.com
# 3       4      Graeme Croisier     9/29/2018       gcroisier3@parallels.com
# 4       5       Jillana Physic     4/19/2018        jphysic4@yellowbook.com
# ..    ...                  ...           ...                            ...
# 995   996    Willie Gravestone     1/17/2018      wgravestonern@typepad.com
# 996   997     Samara McRitchie    12/10/2018    smcritchiero@wikispaces.com
# 997   998  Joceline Josefowicz    10/18/2018  jjosefowiczrp@statcounter.com
# 998   999        Andrei Lestor     1/16/2018          alestorrq@storify.com
# 999  1000       Nikkie Langtry    10/30/2018    nlangtryrr@sciencedaily.com
#
# ...
